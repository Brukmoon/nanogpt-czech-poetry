# %% [markdown]
# ## Load data and split it into train and validation.

# %%
import json
import os
import glob
import tiktoken
import numpy as np

def extract_poems(folder_path):
    poem_lines = []
    for file_path in glob.glob(os.path.join(folder_path, '*.json')):
        with open(file_path, 'r', encoding='us-ascii') as file:
            data = json.load(file)
            for body in data:
                for stanza in body['body']:
                    for line in stanza:
                        poem_lines.append(line['text'])
    return poem_lines

folder_path = r'./corpusCzechVerse/ccv'  # Replace with your folder path
data = extract_poems(folder_path)
n = len(data)
text = '\n'.join(data)
train_text = '\n'.join(data[:int(n*0.9)])
val_text = '\n'.join(data[int(n*0.9):])

# %%
print("Sample:\n", text[0:100])
# Out:
# Sample:
#  Rozpřádá večer sítě své
# a teď je noří ve kouzlo;
# můj bože! a to srdce mé
# zas na ten hrad mi uklouzl

# %% [markdown]
# ## Character encoding

# %% [markdown]
# ### Task: Get unique characters from text.

# %%
keys = sorted(set(list(text)))

# %% [markdown]
# ### Task: Create mappings from characters to integers.

# %%
stoi = dict(zip(keys, [i for i in range(len(keys))]))
itos = dict((v,k) for k,v in stoi.items())
token_map = {'itos':itos, 'stoi':stoi, 'vocab_size':len(stoi)}
import pickle
pickle.dump(token_map, open("meta.pkl", "wb"))

# %% [markdown]
# ### Create encode/decode

# %%
def encode(data: str) -> np.array:
    data_encoded = [stoi[c] for c in data]
    return np.array(data_encoded, dtype=np.uint16)

def decode(data: np.array) -> str:
    data_decoded = ''.join([itos[i] for i in data])
    return data_decoded

# %%
e = encode(train_text[0:100])
print(e)
d = decode(e)
print(d)
# Out:
# [ 44  71  82  72 140 101  60 101   1  78  61 126  61  74   1  75 110  76
#  131   1  75  78 107   1   0  57   1  76  61 128   1  66  61   1  70  71
#  140 110   1  78  61   1  67  71  77  82  68  71  24   0  69 148  66   1
#   58  71 151  61   2   1  57   1  76  71   1  75  74  60  59  61   1  69
#  107   0  82  57  75   1  70  57   1  76  61  70   1  64  74  57  60   1
#   69  65   1  77  67  68  71  77  82  68]
# Rozpřádá večer sítě své
# a teď je noří ve kouzlo;
# můj bože! a to srdce mé
# zas na ten hrad mi uklouzl

# %%
train_ids = encode(train_text)
val_ids = encode(val_text)
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fbf5c418220>>
# Traceback (most recent call last):
#   File "/home/michal-hlousek/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 train_ids = encode(train_text)
#       2 val_ids = encode(val_text)
#
# Cell In[88], line 3, in encode(data)
#       1 def encode(data: str) -> np.array:
#       2     data_encoded = [stoi[c] for c in data]
# ----> 3     return np.array(data_encoded, dtype=np.uint16)
#
# KeyboardInterrupt:

# %%
train_ids.tofile('train.bin')
val_ids.tofile('val.bin')

# %% [markdown]
# ## Byte pair encoding

# %%
import re
from collections import Counter, defaultdict


def build_vocab(corpus: str) -> dict:
    """Step 1. Build vocab from text corpus"""

    # Separate each char in word by space and add mark end of token
    # I have included a character blacklist there, I know it might not be a good idea, but I hated having m.-type tokens.
    tokens = [" ".join(word.replace(".","").replace(",","").replace(";","")) + " </w>" for word in corpus.split()] 
    
    # Count frequency of tokens in corpus
    vocab = Counter(tokens)  

    return vocab


def get_stats(vocab: dict) -> dict:
    """Step 2. Get counts of pairs of consecutive symbols"""

    pairs = defaultdict(int)
    for word, frequency in vocab.items():
        symbols = word.split()

        # Counting up occurrences of pairs
        for i in range(len(symbols) - 1):
            pairs[symbols[i], symbols[i + 1]] += frequency

    return pairs


def merge_vocab(pair: tuple, v_in: dict) -> dict:
    """Step 3. Merge all occurrences of the most frequent pair"""
    
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    
    for word in v_in:
        # replace most frequent pair in all vocabulary
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]

    return v_out

# %%
vocab = build_vocab(text)
num_merges = 500  # Hyperparameter
for i in range(num_merges):
    pairs = get_stats(vocab)  # Step 2
    if not pairs:
        break
    # step 3
    best = max(pairs, key=pairs.get)
    print(f"Iteration {i} out of {num_merges}. Pair = {best}, Frequency = {pairs.get(best)}")
    vocab = merge_vocab(best, vocab)
# Out:
# Iteration 0 out of 500. Pair = ('e', '</w>'), Frequency = 1375001
# Iteration 1 out of 500. Pair = ('a', '</w>'), Frequency = 1125683
# Iteration 2 out of 500. Pair = ('u', '</w>'), Frequency = 815594
# Iteration 3 out of 500. Pair = ('í', '</w>'), Frequency = 771726
# Iteration 4 out of 500. Pair = ('m', '</w>'), Frequency = 746950
# Iteration 5 out of 500. Pair = ('i', '</w>'), Frequency = 744478
# Iteration 6 out of 500. Pair = ('o', '</w>'), Frequency = 728064
# Iteration 7 out of 500. Pair = ('c', 'h'), Frequency = 684931
# Iteration 8 out of 500. Pair = ('s', 't'), Frequency = 626058
# Iteration 9 out of 500. Pair = ('y', '</w>'), Frequency = 624775
# Iteration 10 out of 500. Pair = ('k', '</w>'), Frequency = 450457
# Iteration 11 out of 500. Pair = ('l', '</w>'), Frequency = 428481
# Iteration 12 out of 500. Pair = ('e', 'n'), Frequency = 425558
# Iteration 13 out of 500. Pair = ('v', '</w>'), Frequency = 421120
# Iteration 14 out of 500. Pair = ('é', '</w>'), Frequency = 372391
# Iteration 15 out of 500. Pair = ('á', '</w>'), Frequency = 368385
# Iteration 16 out of 500. Pair = ('n', 'e'), Frequency = 352903
# Iteration 17 out of 500. Pair = ('r', 'o'), Frequency = 351273
# Iteration 18 out of 500. Pair = ('s', 'e</w>'), Frequency = 340193
# Iteration 19 out of 500. Pair = ('ch', '</w>'), Frequency = 329245
# Iteration 20 out of 500. Pair = ('p', 'o'), Frequency = 325233
# Iteration 21 out of 500. Pair = ('ě', '</w>'), Frequency = 303698
# Iteration 22 out of 500. Pair = ('r', 'a'), Frequency = 300573
# Iteration 23 out of 500. Pair = ('l', 'a'), Frequency = 293559
# Iteration 24 out of 500. Pair = ('o', 'u</w>'), Frequency = 291057
# Iteration 25 out of 500. Pair = ('l', 'e'), Frequency = 281376
# Iteration 26 out of 500. Pair = ('ž', '</w>'), Frequency = 280621
# Iteration 27 out of 500. Pair = ('ý', '</w>'), Frequency = 267727
# Iteration 28 out of 500. Pair = ('s', '</w>'), Frequency = 241437
# Iteration 29 out of 500. Pair = ('j', 'e'), Frequency = 236909
# Iteration 30 out of 500. Pair = ('v', 'ě'), Frequency = 230061
# Iteration 31 out of 500. Pair = ('a', 'k</w>'), Frequency = 226987
# Iteration 32 out of 500. Pair = ('e', 'm</w>'), Frequency = 222596
# Iteration 33 out of 500. Pair = ('t', '</w>'), Frequency = 222040
# Iteration 34 out of 500. Pair = ('s', 'k'), Frequency = 209178
# Iteration 35 out of 500. Pair = ('n', 'a</w>'), Frequency = 202100
# Iteration 36 out of 500. Pair = ('r', 'á'), Frequency = 201159
# Iteration 37 out of 500. Pair = ('d', '</w>'), Frequency = 195233
# Iteration 38 out of 500. Pair = ('o', 'u'), Frequency = 194882
# Iteration 39 out of 500. Pair = ('–', '</w>'), Frequency = 194554
# Iteration 40 out of 500. Pair = ('ř', 'e'), Frequency = 174603
# Iteration 41 out of 500. Pair = ('!', '</w>'), Frequency = 169102
# Iteration 42 out of 500. Pair = ('n', 'a'), Frequency = 166117
# Iteration 43 out of 500. Pair = ('l', 'a</w>'), Frequency = 164295
# Iteration 44 out of 500. Pair = ('en', '</w>'), Frequency = 161010
# Iteration 45 out of 500. Pair = ('s', 'v'), Frequency = 157259
# Iteration 46 out of 500. Pair = ('o', 'v'), Frequency = 156635
# Iteration 47 out of 500. Pair = ('n', 'í</w>'), Frequency = 155503
# Iteration 48 out of 500. Pair = ('l', 'i'), Frequency = 154854
# Iteration 49 out of 500. Pair = ('t', 'e'), Frequency = 153445
# Iteration 50 out of 500. Pair = ('j', 'e</w>'), Frequency = 149736
# Iteration 51 out of 500. Pair = ('z', 'a'), Frequency = 143062
# Iteration 52 out of 500. Pair = ('c', 'e</w>'), Frequency = 141471
# Iteration 53 out of 500. Pair = ('n', 'ě</w>'), Frequency = 130836
# Iteration 54 out of 500. Pair = ('ř', 'í'), Frequency = 129679
# Iteration 55 out of 500. Pair = ('k', 'o'), Frequency = 129386
# Iteration 56 out of 500. Pair = ('k', 'd'), Frequency = 127563
# Iteration 57 out of 500. Pair = ('v', 'o'), Frequency = 126314
# Iteration 58 out of 500. Pair = ('z', '</w>'), Frequency = 125182
# Iteration 59 out of 500. Pair = ('n', 'á'), Frequency = 124215
# Iteration 60 out of 500. Pair = ('o', 'b'), Frequency = 122891
# Iteration 61 out of 500. Pair = ('l', 'á'), Frequency = 121055
# Iteration 62 out of 500. Pair = ('ů', '</w>'), Frequency = 116913
# Iteration 63 out of 500. Pair = ('ý', 'ch</w>'), Frequency = 116757
# Iteration 64 out of 500. Pair = ('l', 'i</w>'), Frequency = 114446
# Iteration 65 out of 500. Pair = ('h', 'o</w>'), Frequency = 114228
# Iteration 66 out of 500. Pair = ('n', 'i'), Frequency = 113299
# Iteration 67 out of 500. Pair = ('n', 'ě'), Frequency = 112545
# Iteration 68 out of 500. Pair = ('r', 'u'), Frequency = 112513
# Iteration 69 out of 500. Pair = ('v', 'š'), Frequency = 111351
# Iteration 70 out of 500. Pair = ('í', 'm</w>'), Frequency = 110768
# Iteration 71 out of 500. Pair = ('j', 'i'), Frequency = 109814
# Iteration 72 out of 500. Pair = ('j', '</w>'), Frequency = 109544
# Iteration 73 out of 500. Pair = ('l', 'u'), Frequency = 108779
# Iteration 74 out of 500. Pair = ('z', 'd'), Frequency = 108523
# Iteration 75 out of 500. Pair = ('p', 'a'), Frequency = 107275
# Iteration 76 out of 500. Pair = ('t', 'a'), Frequency = 104167
# Iteration 77 out of 500. Pair = ('o', 'd'), Frequency = 104081
# Iteration 78 out of 500. Pair = ('j', 's'), Frequency = 102397
# Iteration 79 out of 500. Pair = ('v', 'e'), Frequency = 99346
# Iteration 80 out of 500. Pair = ('n', 'o'), Frequency = 98966
# Iteration 81 out of 500. Pair = ('v', 'a'), Frequency = 98247
# Iteration 82 out of 500. Pair = ('t', 'o</w>'), Frequency = 97729
# Iteration 83 out of 500. Pair = ('t', 'ě'), Frequency = 96604
# Iteration 84 out of 500. Pair = ('k', 'a'), Frequency = 96379
# Iteration 85 out of 500. Pair = ('ž', 'e</w>'), Frequency = 95834
# Iteration 86 out of 500. Pair = ('l', 'e</w>'), Frequency = 95526
# Iteration 87 out of 500. Pair = ('t', 'i'), Frequency = 95040
# Iteration 88 out of 500. Pair = ('n', 'é</w>'), Frequency = 94036
# Iteration 89 out of 500. Pair = ('b', 'y'), Frequency = 93605
# Iteration 90 out of 500. Pair = ('j', 'a'), Frequency = 93391
# Iteration 91 out of 500. Pair = ('v', 'í'), Frequency = 92896
# Iteration 92 out of 500. Pair = ('v', 'á'), Frequency = 92337
# Iteration 93 out of 500. Pair = ('n', '</w>'), Frequency = 92272
# Iteration 94 out of 500. Pair = ('m', 'i</w>'), Frequency = 91982
# Iteration 95 out of 500. Pair = ('j', 'ak</w>'), Frequency = 91558
# Iteration 96 out of 500. Pair = ('d', 'ě'), Frequency = 90336
# Iteration 97 out of 500. Pair = ('j', 'í</w>'), Frequency = 90034
# Iteration 98 out of 500. Pair = ('k', 'y</w>'), Frequency = 89438
# Iteration 99 out of 500. Pair = ('č', 'e'), Frequency = 89346
# Iteration 100 out of 500. Pair = ('t', 'i</w>'), Frequency = 88396
# Iteration 101 out of 500. Pair = ('m', 'o'), Frequency = 87969
# Iteration 102 out of 500. Pair = ('l', 'o</w>'), Frequency = 87290
# Iteration 103 out of 500. Pair = ('ř', 'i'), Frequency = 86895
# Iteration 104 out of 500. Pair = ('c', '</w>'), Frequency = 86360
# Iteration 105 out of 500. Pair = ('m', 'ě'), Frequency = 84342
# Iteration 106 out of 500. Pair = (':', '</w>'), Frequency = 83805
# Iteration 107 out of 500. Pair = ('n', 'e</w>'), Frequency = 83486
# Iteration 108 out of 500. Pair = ('k', 'u</w>'), Frequency = 83439
# Iteration 109 out of 500. Pair = ('l', 'o'), Frequency = 82374
# Iteration 110 out of 500. Pair = ('v', 'i'), Frequency = 82231
# Iteration 111 out of 500. Pair = ('ý', 'm</w>'), Frequency = 82139
# Iteration 112 out of 500. Pair = ('b', 'o'), Frequency = 81796
# Iteration 113 out of 500. Pair = ('l', 'í'), Frequency = 81037
# Iteration 114 out of 500. Pair = ('d', 'o'), Frequency = 80770
# Iteration 115 out of 500. Pair = ('st', '</w>'), Frequency = 79662
# Iteration 116 out of 500. Pair = ('n', 'ý</w>'), Frequency = 79557
# Iteration 117 out of 500. Pair = ('p', 'ro'), Frequency = 77622
# Iteration 118 out of 500. Pair = ('š', '</w>'), Frequency = 77144
# Iteration 119 out of 500. Pair = ('h', 'o'), Frequency = 76932
# Iteration 120 out of 500. Pair = ('k', 'o</w>'), Frequency = 76579
# Iteration 121 out of 500. Pair = ('m', 'a'), Frequency = 76362
# Iteration 122 out of 500. Pair = ('u', 'd'), Frequency = 75944
# Iteration 123 out of 500. Pair = ('v', 'y'), Frequency = 75613
# Iteration 124 out of 500. Pair = ('s', 'e'), Frequency = 75481
# Iteration 125 out of 500. Pair = ('n', 'ou</w>'), Frequency = 75268
# Iteration 126 out of 500. Pair = ('ž', 'i'), Frequency = 75199
# Iteration 127 out of 500. Pair = ('A', '</w>'), Frequency = 75043
# Iteration 128 out of 500. Pair = ('t', 'o'), Frequency = 74907
# Iteration 129 out of 500. Pair = ('n', 'í'), Frequency = 72599
# Iteration 130 out of 500. Pair = ('p', 'ře'), Frequency = 71933
# Iteration 131 out of 500. Pair = ('ť', '</w>'), Frequency = 71803
# Iteration 132 out of 500. Pair = ('m', 'u</w>'), Frequency = 71778
# Iteration 133 out of 500. Pair = ('?', '</w>'), Frequency = 71404
# Iteration 134 out of 500. Pair = ('l', 'y</w>'), Frequency = 70356
# Iteration 135 out of 500. Pair = ('st', 'a'), Frequency = 69964
# Iteration 136 out of 500. Pair = ('d', 'u'), Frequency = 69214
# Iteration 137 out of 500. Pair = ('c', 'i</w>'), Frequency = 67993
# Iteration 138 out of 500. Pair = ('ro', 'z'), Frequency = 67436
# Iteration 139 out of 500. Pair = ('c', 'e'), Frequency = 66685
# Iteration 140 out of 500. Pair = ('“', '</w>'), Frequency = 66445
# Iteration 141 out of 500. Pair = ('d', 'á'), Frequency = 65806
# Iteration 142 out of 500. Pair = ('t', 'í</w>'), Frequency = 65787
# Iteration 143 out of 500. Pair = ('b', 'y</w>'), Frequency = 64630
# Iteration 144 out of 500. Pair = ('m', 'i'), Frequency = 64175
# Iteration 145 out of 500. Pair = ('d', 'i'), Frequency = 63737
# Iteration 146 out of 500. Pair = ('r', '</w>'), Frequency = 63607
# Iteration 147 out of 500. Pair = ('t', 'v'), Frequency = 62268
# Iteration 148 out of 500. Pair = ('m', 'í'), Frequency = 61710
# Iteration 149 out of 500. Pair = ('s', 'l'), Frequency = 61400
# Iteration 150 out of 500. Pair = ('k', 'a</w>'), Frequency = 61143
# Iteration 151 out of 500. Pair = ('é', 'm</w>'), Frequency = 60836
# Iteration 152 out of 500. Pair = ('p', 'r'), Frequency = 60654
# Iteration 153 out of 500. Pair = ('r', 'd'), Frequency = 60442
# Iteration 154 out of 500. Pair = ('š', 'e'), Frequency = 59534
# Iteration 155 out of 500. Pair = ('t', 'ě</w>'), Frequency = 59271
# Iteration 156 out of 500. Pair = ('t', 'u</w>'), Frequency = 58426
# Iteration 157 out of 500. Pair = ('d', 'o</w>'), Frequency = 58277
# Iteration 158 out of 500. Pair = ('z', 'á'), Frequency = 58276
# Iteration 159 out of 500. Pair = ('d', 'a'), Frequency = 57743
# Iteration 160 out of 500. Pair = ('n', 'y</w>'), Frequency = 56907
# Iteration 161 out of 500. Pair = ('n', 'á</w>'), Frequency = 54559
# Iteration 162 out of 500. Pair = ('s', 'vě'), Frequency = 54482
# Iteration 163 out of 500. Pair = ('m', 'u'), Frequency = 54442
# Iteration 164 out of 500. Pair = ('k', 'rá'), Frequency = 54274
# Iteration 165 out of 500. Pair = ('z', 'e'), Frequency = 54140
# Iteration 166 out of 500. Pair = ('t', 'y</w>'), Frequency = 52777
# Iteration 167 out of 500. Pair = ('b', 'e'), Frequency = 52665
# Iteration 168 out of 500. Pair = ('š', 'e</w>'), Frequency = 52555
# Iteration 169 out of 500. Pair = ('d', 'y</w>'), Frequency = 52408
# Iteration 170 out of 500. Pair = ('p', 'ě'), Frequency = 52226
# Iteration 171 out of 500. Pair = ('h', 'la'), Frequency = 51758
# Iteration 172 out of 500. Pair = ('t', 'r'), Frequency = 50545
# Iteration 173 out of 500. Pair = ('j', 'en</w>'), Frequency = 50503
# Iteration 174 out of 500. Pair = ('js', 'em</w>'), Frequency = 50406
# Iteration 175 out of 500. Pair = ('p', 'í'), Frequency = 49645
# Iteration 176 out of 500. Pair = ('kd', 'y'), Frequency = 48907
# Iteration 177 out of 500. Pair = ('h', 'a'), Frequency = 48829
# Iteration 178 out of 500. Pair = ('č', 'i'), Frequency = 48604
# Iteration 179 out of 500. Pair = ('s', 'i</w>'), Frequency = 48398
# Iteration 180 out of 500. Pair = ('c', 'o</w>'), Frequency = 47435
# Iteration 181 out of 500. Pair = ('n', 'i</w>'), Frequency = 46611
# Iteration 182 out of 500. Pair = ('š', 'í</w>'), Frequency = 46571
# Iteration 183 out of 500. Pair = ('v', 'z'), Frequency = 46540
# Iteration 184 out of 500. Pair = ('p', 'ra'), Frequency = 45233
# Iteration 185 out of 500. Pair = ('j', 'í'), Frequency = 44998
# Iteration 186 out of 500. Pair = ('d', 'e'), Frequency = 44894
# Iteration 187 out of 500. Pair = ('m', 'á'), Frequency = 44855
# Iteration 188 out of 500. Pair = ('z', 'a</w>'), Frequency = 44713
# Iteration 189 out of 500. Pair = ('s', 'rd'), Frequency = 44479
# Iteration 190 out of 500. Pair = ('n', 'u'), Frequency = 44367
# Iteration 191 out of 500. Pair = ('v', 'e</w>'), Frequency = 44327
# Iteration 192 out of 500. Pair = ('č', '</w>'), Frequency = 44257
# Iteration 193 out of 500. Pair = ('c', 'í</w>'), Frequency = 43543
# Iteration 194 out of 500. Pair = ('j', 'i</w>'), Frequency = 43425
# Iteration 195 out of 500. Pair = ('t', 'a</w>'), Frequency = 43330
# Iteration 196 out of 500. Pair = ('st', 'i</w>'), Frequency = 43089
# Iteration 197 out of 500. Pair = ('n', 'o</w>'), Frequency = 42902
# Iteration 198 out of 500. Pair = ('ř', 'e</w>'), Frequency = 42856
# Iteration 199 out of 500. Pair = ('s', 'a'), Frequency = 42372
# Iteration 200 out of 500. Pair = ('l', 'ou'), Frequency = 42141
# Iteration 201 out of 500. Pair = ('v', 'á</w>'), Frequency = 42092
# Iteration 202 out of 500. Pair = ('é', 'ho</w>'), Frequency = 41815
# Iteration 203 out of 500. Pair = ('vš', 'e'), Frequency = 41671
# Iteration 204 out of 500. Pair = ('ď', '</w>'), Frequency = 41354
# Iteration 205 out of 500. Pair = ('t', 'e</w>'), Frequency = 41063
# Iteration 206 out of 500. Pair = ('d', 'í'), Frequency = 40931
# Iteration 207 out of 500. Pair = ('m', 'e</w>'), Frequency = 40571
# Iteration 208 out of 500. Pair = ('t', 'á'), Frequency = 40328
# Iteration 209 out of 500. Pair = ('č', 'í</w>'), Frequency = 40232
# Iteration 210 out of 500. Pair = ('r', 'e'), Frequency = 39810
# Iteration 211 out of 500. Pair = ('ř', 'í</w>'), Frequency = 39701
# Iteration 212 out of 500. Pair = ('m', 'e'), Frequency = 39359
# Iteration 213 out of 500. Pair = ('n', 'u</w>'), Frequency = 39336
# Iteration 214 out of 500. Pair = ('v', 'í</w>'), Frequency = 39205
# Iteration 215 out of 500. Pair = ('na', 'd</w>'), Frequency = 39050
# Iteration 216 out of 500. Pair = ('kdy', 'ž</w>'), Frequency = 38775
# Iteration 217 out of 500. Pair = ('t', 'ak</w>'), Frequency = 38670
# Iteration 218 out of 500. Pair = ('p', 'á'), Frequency = 38335
# Iteration 219 out of 500. Pair = ('p', 'o</w>'), Frequency = 38138
# Iteration 220 out of 500. Pair = ('en', 'í</w>'), Frequency = 38093
# Iteration 221 out of 500. Pair = ('ů', 'j</w>'), Frequency = 37844
# Iteration 222 out of 500. Pair = ('la', 'd'), Frequency = 37383
# Iteration 223 out of 500. Pair = ('p', 'l'), Frequency = 36992
# Iteration 224 out of 500. Pair = ('ň', '</w>'), Frequency = 36789
# Iteration 225 out of 500. Pair = ('p', 'e'), Frequency = 36679
# Iteration 226 out of 500. Pair = ('ž', 'í</w>'), Frequency = 36371
# Iteration 227 out of 500. Pair = ('z', 'e</w>'), Frequency = 36344
# Iteration 228 out of 500. Pair = ('p', 'ři'), Frequency = 36150
# Iteration 229 out of 500. Pair = ('s', 'í'), Frequency = 36043
# Iteration 230 out of 500. Pair = ('ja', 'ko</w>'), Frequency = 35798
# Iteration 231 out of 500. Pair = ('b', 'ud'), Frequency = 34676
# Iteration 232 out of 500. Pair = ('k', 'á'), Frequency = 34361
# Iteration 233 out of 500. Pair = ('j', 'en'), Frequency = 34341
# Iteration 234 out of 500. Pair = ('s', 'i'), Frequency = 34294
# Iteration 235 out of 500. Pair = ('ž', 'e'), Frequency = 34166
# Iteration 236 out of 500. Pair = ('c', 'í'), Frequency = 33585
# Iteration 237 out of 500. Pair = ('h', '</w>'), Frequency = 33572
# Iteration 238 out of 500. Pair = ('d', 'e</w>'), Frequency = 33390
# Iteration 239 out of 500. Pair = ('d', 'u</w>'), Frequency = 33366
# Iteration 240 out of 500. Pair = ('n', 'ých</w>'), Frequency = 33319
# Iteration 241 out of 500. Pair = ('l', 'ý</w>'), Frequency = 33242
# Iteration 242 out of 500. Pair = ('ž', 'd'), Frequency = 32782
# Iteration 243 out of 500. Pair = ('p', 'ří'), Frequency = 32766
# Iteration 244 out of 500. Pair = ('N', 'e'), Frequency = 32575
# Iteration 245 out of 500. Pair = ('t', 'í'), Frequency = 32406
# Iteration 246 out of 500. Pair = ('l', 'í</w>'), Frequency = 32357
# Iteration 247 out of 500. Pair = ('r', 'u</w>'), Frequency = 32355
# Iteration 248 out of 500. Pair = ('l', 'é</w>'), Frequency = 32195
# Iteration 249 out of 500. Pair = ('m', 'á</w>'), Frequency = 32051
# Iteration 250 out of 500. Pair = ('p', 'la'), Frequency = 31620
# Iteration 251 out of 500. Pair = ('č', 'a'), Frequency = 31419
# Iteration 252 out of 500. Pair = ('st', 'á'), Frequency = 31192
# Iteration 253 out of 500. Pair = ('b', 'í'), Frequency = 31172
# Iteration 254 out of 500. Pair = ('le', 'd'), Frequency = 30965
# Iteration 255 out of 500. Pair = ('ř', 'i</w>'), Frequency = 30765
# Iteration 256 out of 500. Pair = ('k', 'é</w>'), Frequency = 30663
# Iteration 257 out of 500. Pair = ('s', 'lu'), Frequency = 30625
# Iteration 258 out of 500. Pair = ('r', 'y'), Frequency = 30546
# Iteration 259 out of 500. Pair = ('l', 'en'), Frequency = 30435
# Iteration 260 out of 500. Pair = ('vš', 'ak</w>'), Frequency = 30291
# Iteration 261 out of 500. Pair = ('ne', 'b'), Frequency = 30090
# Iteration 262 out of 500. Pair = ('V', '</w>'), Frequency = 29966
# Iteration 263 out of 500. Pair = ('t', 'é</w>'), Frequency = 29903
# Iteration 264 out of 500. Pair = ('st', 'í</w>'), Frequency = 29872
# Iteration 265 out of 500. Pair = ('je', 'ž</w>'), Frequency = 29822
# Iteration 266 out of 500. Pair = ('je', 'd'), Frequency = 29466
# Iteration 267 out of 500. Pair = ('m', 'r'), Frequency = 29433
# Iteration 268 out of 500. Pair = ('kd', 'e</w>'), Frequency = 29156
# Iteration 269 out of 500. Pair = ('l', 'é'), Frequency = 29064
# Iteration 270 out of 500. Pair = ('’', '</w>'), Frequency = 28962
# Iteration 271 out of 500. Pair = ('p', 'i'), Frequency = 28720
# Iteration 272 out of 500. Pair = ('!', '“</w>'), Frequency = 28643
# Iteration 273 out of 500. Pair = ('b', 'i'), Frequency = 28551
# Iteration 274 out of 500. Pair = ('b', 'a'), Frequency = 28485
# Iteration 275 out of 500. Pair = ('n', 'ov'), Frequency = 28474
# Iteration 276 out of 500. Pair = ('k', 'ou</w>'), Frequency = 28339
# Iteration 277 out of 500. Pair = ('v', 'y</w>'), Frequency = 28332
# Iteration 278 out of 500. Pair = ('t', 'en</w>'), Frequency = 28227
# Iteration 279 out of 500. Pair = ('c', 'i'), Frequency = 27842
# Iteration 280 out of 500. Pair = ('p', 'u'), Frequency = 27772
# Iteration 281 out of 500. Pair = ('li', 'd'), Frequency = 27698
# Iteration 282 out of 500. Pair = ('srd', 'ce</w>'), Frequency = 27571
# Iteration 283 out of 500. Pair = ('ji', 'ž</w>'), Frequency = 27477
# Iteration 284 out of 500. Pair = ('k', 'á</w>'), Frequency = 27469
# Iteration 285 out of 500. Pair = ('ta', 'm</w>'), Frequency = 27433
# Iteration 286 out of 500. Pair = ('je', 'ho</w>'), Frequency = 27381
# Iteration 287 out of 500. Pair = ('ž', 'en'), Frequency = 27370
# Iteration 288 out of 500. Pair = ('d', 'ob'), Frequency = 27270
# Iteration 289 out of 500. Pair = ('sv', 'é</w>'), Frequency = 27128
# Iteration 290 out of 500. Pair = ('le', 'm</w>'), Frequency = 27041
# Iteration 291 out of 500. Pair = ('m', 'y'), Frequency = 26965
# Iteration 292 out of 500. Pair = ('ř', '</w>'), Frequency = 26655
# Iteration 293 out of 500. Pair = ('v', 'ý'), Frequency = 26644
# Iteration 294 out of 500. Pair = ('by', 'l</w>'), Frequency = 26509
# Iteration 295 out of 500. Pair = ('t', 'u'), Frequency = 26392
# Iteration 296 out of 500. Pair = ('l', 'á</w>'), Frequency = 26361
# Iteration 297 out of 500. Pair = ('ov', 'a'), Frequency = 26239
# Iteration 298 out of 500. Pair = ('r', 'ů'), Frequency = 26238
# Iteration 299 out of 500. Pair = ('lá', 'sk'), Frequency = 26127
# Iteration 300 out of 500. Pair = ('le', 's'), Frequency = 25935
# Iteration 301 out of 500. Pair = ('k', 'em</w>'), Frequency = 25795
# Iteration 302 out of 500. Pair = ('k', 'te'), Frequency = 25774
# Iteration 303 out of 500. Pair = ('u', 'ž</w>'), Frequency = 25476
# Iteration 304 out of 500. Pair = ('š', 'i'), Frequency = 25403
# Iteration 305 out of 500. Pair = ('j', 'á</w>'), Frequency = 25003
# Iteration 306 out of 500. Pair = ('k', 'u'), Frequency = 24937
# Iteration 307 out of 500. Pair = ('k', 'vě'), Frequency = 24904
# Iteration 308 out of 500. Pair = ('ná', 'm</w>'), Frequency = 24503
# Iteration 309 out of 500. Pair = ('k', 'ý</w>'), Frequency = 24335
# Iteration 310 out of 500. Pair = ('po', 'u'), Frequency = 24324
# Iteration 311 out of 500. Pair = ('v', 'la'), Frequency = 24269
# Iteration 312 out of 500. Pair = ('v', 'ě</w>'), Frequency = 24078
# Iteration 313 out of 500. Pair = ('n', 'ým</w>'), Frequency = 24001
# Iteration 314 out of 500. Pair = ('m', 'ě</w>'), Frequency = 23871
# Iteration 315 out of 500. Pair = ('š', 'i</w>'), Frequency = 23863
# Iteration 316 out of 500. Pair = ('p', 'rá'), Frequency = 23848
# Iteration 317 out of 500. Pair = ('s', 'á'), Frequency = 23795
# Iteration 318 out of 500. Pair = ('če', 'r'), Frequency = 23783
# Iteration 319 out of 500. Pair = ('v', 'é</w>'), Frequency = 23642
# Iteration 320 out of 500. Pair = ('n', 'ím</w>'), Frequency = 23609
# Iteration 321 out of 500. Pair = ('ch', 'u</w>'), Frequency = 23580
# Iteration 322 out of 500. Pair = ('b', 'u'), Frequency = 23394
# Iteration 323 out of 500. Pair = ('z', 'ra'), Frequency = 23342
# Iteration 324 out of 500. Pair = ('st', 'o'), Frequency = 23335
# Iteration 325 out of 500. Pair = ('k', 'ů</w>'), Frequency = 23247
# Iteration 326 out of 500. Pair = ('m', 'en'), Frequency = 23143
# Iteration 327 out of 500. Pair = ('v', 'a</w>'), Frequency = 23107
# Iteration 328 out of 500. Pair = ('z', 'la'), Frequency = 22978
# Iteration 329 out of 500. Pair = ('v', 'u</w>'), Frequency = 22752
# Iteration 330 out of 500. Pair = ('jen', 'ž</w>'), Frequency = 22503
# Iteration 331 out of 500. Pair = ('d', 'í</w>'), Frequency = 22449
# Iteration 332 out of 500. Pair = ('š', 'í'), Frequency = 22392
# Iteration 333 out of 500. Pair = ('h', 'á'), Frequency = 21944
# Iteration 334 out of 500. Pair = ('č', 'í'), Frequency = 21848
# Iteration 335 out of 500. Pair = ('h', 'ro'), Frequency = 21777
# Iteration 336 out of 500. Pair = ('kd', 'y</w>'), Frequency = 21711
# Iteration 337 out of 500. Pair = ('r', 'á</w>'), Frequency = 21579
# Iteration 338 out of 500. Pair = ('h', 'u</w>'), Frequency = 21548
# Iteration 339 out of 500. Pair = ('r', 'y</w>'), Frequency = 21479
# Iteration 340 out of 500. Pair = ('d', 'a</w>'), Frequency = 21427
# Iteration 341 out of 500. Pair = ('st', 'i'), Frequency = 21285
# Iteration 342 out of 500. Pair = ('s', 'la'), Frequency = 21178
# Iteration 343 out of 500. Pair = ('b', 'ra'), Frequency = 21044
# Iteration 344 out of 500. Pair = ('m', 'ne</w>'), Frequency = 21033
# Iteration 345 out of 500. Pair = ('č', 'i</w>'), Frequency = 20987
# Iteration 346 out of 500. Pair = ('ob', 'ě</w>'), Frequency = 20982
# Iteration 347 out of 500. Pair = ('ne', 's'), Frequency = 20833
# Iteration 348 out of 500. Pair = ('ů', 'm</w>'), Frequency = 20636
# Iteration 349 out of 500. Pair = ('b', 'á'), Frequency = 20609
# Iteration 350 out of 500. Pair = ('t', 'á</w>'), Frequency = 20519
# Iteration 351 out of 500. Pair = ('ži', 'vo'), Frequency = 20479
# Iteration 352 out of 500. Pair = ('k', 'r'), Frequency = 20458
# Iteration 353 out of 500. Pair = ('ch', 'a'), Frequency = 20411
# Iteration 354 out of 500. Pair = ('st', 'e'), Frequency = 20397
# Iteration 355 out of 500. Pair = ('ji', 'ch</w>'), Frequency = 20323
# Iteration 356 out of 500. Pair = ('v', 'zd'), Frequency = 20297
# Iteration 357 out of 500. Pair = ('a', 'ž</w>'), Frequency = 20283
# Iteration 358 out of 500. Pair = ('š', 'tě</w>'), Frequency = 20250
# Iteration 359 out of 500. Pair = ('ř', 'á'), Frequency = 20216
# Iteration 360 out of 500. Pair = ('r', 'a</w>'), Frequency = 20181
# Iteration 361 out of 500. Pair = ('p', 'ak</w>'), Frequency = 19897
# Iteration 362 out of 500. Pair = ('p', 'lá'), Frequency = 19798
# Iteration 363 out of 500. Pair = ('š', 'tě'), Frequency = 19784
# Iteration 364 out of 500. Pair = ('m', 'é</w>'), Frequency = 19783
# Iteration 365 out of 500. Pair = ('h', 'ra'), Frequency = 19666
# Iteration 366 out of 500. Pair = ('l', 'u</w>'), Frequency = 19606
# Iteration 367 out of 500. Pair = ('n', 'ou'), Frequency = 19545
# Iteration 368 out of 500. Pair = ('krá', 's'), Frequency = 19456
# Iteration 369 out of 500. Pair = ('m', 'y</w>'), Frequency = 19340
# Iteration 370 out of 500. Pair = ('v', 'ou</w>'), Frequency = 19303
# Iteration 371 out of 500. Pair = ('h', 'y</w>'), Frequency = 19183
# Iteration 372 out of 500. Pair = ('st', 'í'), Frequency = 19160
# Iteration 373 out of 500. Pair = ('sv', 'a'), Frequency = 19127
# Iteration 374 out of 500. Pair = ('s', 'mě'), Frequency = 19054
# Iteration 375 out of 500. Pair = ('d', 'á</w>'), Frequency = 18888
# Iteration 376 out of 500. Pair = ('svě', 't'), Frequency = 18736
# Iteration 377 out of 500. Pair = ('P', 'o'), Frequency = 18666
# Iteration 378 out of 500. Pair = ('ka', 'žd'), Frequency = 18628
# Iteration 379 out of 500. Pair = ('za', 's</w>'), Frequency = 18601
# Iteration 380 out of 500. Pair = ('t', 'ou'), Frequency = 18593
# Iteration 381 out of 500. Pair = ('z', 'í</w>'), Frequency = 18549
# Iteration 382 out of 500. Pair = ('kd', 'o</w>'), Frequency = 18543
# Iteration 383 out of 500. Pair = ('r', 'ý</w>'), Frequency = 18502
# Iteration 384 out of 500. Pair = ('vš', 'e</w>'), Frequency = 18295
# Iteration 385 out of 500. Pair = ('h', 'le'), Frequency = 18270
# Iteration 386 out of 500. Pair = ('pr', 'o</w>'), Frequency = 18191
# Iteration 387 out of 500. Pair = ('b', 'ě'), Frequency = 18170
# Iteration 388 out of 500. Pair = ('slu', 'n'), Frequency = 18140
# Iteration 389 out of 500. Pair = ('ch', 'o'), Frequency = 18085
# Iteration 390 out of 500. Pair = ('k', 'ou'), Frequency = 18004
# Iteration 391 out of 500. Pair = ('s', 'po'), Frequency = 17868
# Iteration 392 out of 500. Pair = ('h', 'e'), Frequency = 17849
# Iteration 393 out of 500. Pair = ('r', 'é</w>'), Frequency = 17843
# Iteration 394 out of 500. Pair = ('k', 'ra'), Frequency = 17829
# Iteration 395 out of 500. Pair = ('to', 'm</w>'), Frequency = 17785
# Iteration 396 out of 500. Pair = ('s', 'y'), Frequency = 17734
# Iteration 397 out of 500. Pair = ('h', 'od'), Frequency = 17710
# Iteration 398 out of 500. Pair = ('v', 'ý</w>'), Frequency = 17675
# Iteration 399 out of 500. Pair = ('je', 'st</w>'), Frequency = 17454
# Iteration 400 out of 500. Pair = ('t', 'ím</w>'), Frequency = 17444
# Iteration 401 out of 500. Pair = ('s', 'u'), Frequency = 17382
# Iteration 402 out of 500. Pair = ('sv', 'ou</w>'), Frequency = 17323
# Iteration 403 out of 500. Pair = ('s', 'o'), Frequency = 17247
# Iteration 404 out of 500. Pair = ('m', 'a</w>'), Frequency = 17192
# Iteration 405 out of 500. Pair = ('ž', 'í'), Frequency = 17091
# Iteration 406 out of 500. Pair = ('d', 'ru'), Frequency = 17082
# Iteration 407 out of 500. Pair = ('s', 'em</w>'), Frequency = 16978
# Iteration 408 out of 500. Pair = ('va', 'l</w>'), Frequency = 16941
# Iteration 409 out of 500. Pair = ('v', 'ra'), Frequency = 16934
# Iteration 410 out of 500. Pair = ('N', 'a</w>'), Frequency = 16829
# Iteration 411 out of 500. Pair = ('še', 'l</w>'), Frequency = 16773
# Iteration 412 out of 500. Pair = ('m', 'ně</w>'), Frequency = 16709
# Iteration 413 out of 500. Pair = ('d', 'ra'), Frequency = 16645
# Iteration 414 out of 500. Pair = ('st', 'ra'), Frequency = 16607
# Iteration 415 out of 500. Pair = ('v', 'ů'), Frequency = 16604
# Iteration 416 out of 500. Pair = ('b', '</w>'), Frequency = 16601
# Iteration 417 out of 500. Pair = ('ti', 'ch'), Frequency = 16550
# Iteration 418 out of 500. Pair = ('ro', 'u'), Frequency = 16549
# Iteration 419 out of 500. Pair = ('t', 'vá'), Frequency = 16518
# Iteration 420 out of 500. Pair = ('js', 'i</w>'), Frequency = 16416
# Iteration 421 out of 500. Pair = ('ž', 'dy</w>'), Frequency = 16386
# Iteration 422 out of 500. Pair = ('k', 'y'), Frequency = 16151
# Iteration 423 out of 500. Pair = ('b', 'ý'), Frequency = 16122
# Iteration 424 out of 500. Pair = ('h', 'vě'), Frequency = 16050
# Iteration 425 out of 500. Pair = ('m', 'ra'), Frequency = 16006
# Iteration 426 out of 500. Pair = ('h', 'a</w>'), Frequency = 16002
# Iteration 427 out of 500. Pair = ('ne', 'j'), Frequency = 15992
# Iteration 428 out of 500. Pair = ('po', 'd</w>'), Frequency = 15974
# Iteration 429 out of 500. Pair = ('-', 'li</w>'), Frequency = 15954
# Iteration 430 out of 500. Pair = ('d', 'ne'), Frequency = 15933
# Iteration 431 out of 500. Pair = ('J', 'e'), Frequency = 15879
# Iteration 432 out of 500. Pair = ('be', 'z</w>'), Frequency = 15849
# Iteration 433 out of 500. Pair = ('J', 'ak</w>'), Frequency = 15839
# Iteration 434 out of 500. Pair = ('du', 'še</w>'), Frequency = 15814
# Iteration 435 out of 500. Pair = ('l', 'ou</w>'), Frequency = 15736
# Iteration 436 out of 500. Pair = ('v', 'l'), Frequency = 15724
# Iteration 437 out of 500. Pair = ('js', 'ou</w>'), Frequency = 15701
# Iteration 438 out of 500. Pair = ('b', 'a</w>'), Frequency = 15656
# Iteration 439 out of 500. Pair = ('by', 'ch</w>'), Frequency = 15617
# Iteration 440 out of 500. Pair = ('n', 'ém</w>'), Frequency = 15520
# Iteration 441 out of 500. Pair = ('o', 't'), Frequency = 15489
# Iteration 442 out of 500. Pair = ('ž', 'á'), Frequency = 15463
# Iteration 443 out of 500. Pair = ('h', 'u'), Frequency = 15439
# Iteration 444 out of 500. Pair = ('st', 'ro'), Frequency = 15422
# Iteration 445 out of 500. Pair = ('ve', 'l'), Frequency = 15392
# Iteration 446 out of 500. Pair = ('h', 'á</w>'), Frequency = 15349
# Iteration 447 out of 500. Pair = ('r', 'i'), Frequency = 15267
# Iteration 448 out of 500. Pair = ('pře', 'd</w>'), Frequency = 15100
# Iteration 449 out of 500. Pair = ('B', 'o'), Frequency = 15090
# Iteration 450 out of 500. Pair = ('dě', 'l</w>'), Frequency = 15088
# Iteration 451 out of 500. Pair = ('je', 'ště</w>'), Frequency = 15079
# Iteration 452 out of 500. Pair = ('d', 'y'), Frequency = 15067
# Iteration 453 out of 500. Pair = ('h', 'lu'), Frequency = 15060
# Iteration 454 out of 500. Pair = ('t', 'ře'), Frequency = 14975
# Iteration 455 out of 500. Pair = ('m', 'od'), Frequency = 14898
# Iteration 456 out of 500. Pair = ('t', 'em</w>'), Frequency = 14879
# Iteration 457 out of 500. Pair = ('m', 'l'), Frequency = 14869
# Iteration 458 out of 500. Pair = ('st', 'a</w>'), Frequency = 14867
# Iteration 459 out of 500. Pair = ('sk', 'é</w>'), Frequency = 14852
# Iteration 460 out of 500. Pair = ('ž', 'a'), Frequency = 14833
# Iteration 461 out of 500. Pair = ('v', 'ždy</w>'), Frequency = 14818
# Iteration 462 out of 500. Pair = ('s', 'y</w>'), Frequency = 14777
# Iteration 463 out of 500. Pair = ('b', 'la'), Frequency = 14771
# Iteration 464 out of 500. Pair = ('s', 'ou'), Frequency = 14742
# Iteration 465 out of 500. Pair = ('z', 'i'), Frequency = 14682
# Iteration 466 out of 500. Pair = ('te', 'ď</w>'), Frequency = 14630
# Iteration 467 out of 500. Pair = ('b', 'e</w>'), Frequency = 14559
# Iteration 468 out of 500. Pair = ('sl', 'ov'), Frequency = 14557
# Iteration 469 out of 500. Pair = ('o', 'd</w>'), Frequency = 14551
# Iteration 470 out of 500. Pair = ('ch', 'á'), Frequency = 14531
# Iteration 471 out of 500. Pair = ('t', 'ý</w>'), Frequency = 14490
# Iteration 472 out of 500. Pair = ('č', 'e</w>'), Frequency = 14449
# Iteration 473 out of 500. Pair = ('ná', 's</w>'), Frequency = 14396
# Iteration 474 out of 500. Pair = ('v', 'r'), Frequency = 14352
# Iteration 475 out of 500. Pair = ('b', 'ou'), Frequency = 14312
# Iteration 476 out of 500. Pair = ('m', 'ůj</w>'), Frequency = 14246
# Iteration 477 out of 500. Pair = ('vě', 'č'), Frequency = 14226
# Iteration 478 out of 500. Pair = ('t', 'é'), Frequency = 14220
# Iteration 479 out of 500. Pair = ('n', 'ů</w>'), Frequency = 14167
# Iteration 480 out of 500. Pair = ('Ó', '</w>'), Frequency = 14145
# Iteration 481 out of 500. Pair = ('k', 'ro'), Frequency = 14091
# Iteration 482 out of 500. Pair = ('k', 'le'), Frequency = 14089
# Iteration 483 out of 500. Pair = ('sl', 'y'), Frequency = 13979
# Iteration 484 out of 500. Pair = ('m', 'no'), Frequency = 13976
# Iteration 485 out of 500. Pair = ('pa', 'd'), Frequency = 13971
# Iteration 486 out of 500. Pair = ('vše', 'c'), Frequency = 13966
# Iteration 487 out of 500. Pair = ('t', 'vo'), Frequency = 13860
# Iteration 488 out of 500. Pair = ('v', 'u'), Frequency = 13836
# Iteration 489 out of 500. Pair = ('s', 'í</w>'), Frequency = 13823
# Iteration 490 out of 500. Pair = ('s', 'mu'), Frequency = 13746
# Iteration 491 out of 500. Pair = ('k', 'ří'), Frequency = 13745
# Iteration 492 out of 500. Pair = ('k', 'ov'), Frequency = 13665
# Iteration 493 out of 500. Pair = ('je', 'j</w>'), Frequency = 13663
# Iteration 494 out of 500. Pair = ('k', 'la'), Frequency = 13658
# Iteration 495 out of 500. Pair = ('h', 'ou</w>'), Frequency = 13611
# Iteration 496 out of 500. Pair = ('ne', 'ž</w>'), Frequency = 13602
# Iteration 497 out of 500. Pair = ('sv', 'o'), Frequency = 13518
# Iteration 498 out of 500. Pair = ('z', 'vo'), Frequency = 13475
# Iteration 499 out of 500. Pair = ('t', 'ou</w>'), Frequency = 13274

# %%
def extract_unique_tokens(dictionary):
    unique_tokens = set(keys)
    for key in dictionary.keys():
        # Remove "</w>" tokens from the key
        key = key.replace("</w>", "")
        
        # Extract unique characters/bigrams/trigrams separated by a space
        tokens = key.split()
        for token in tokens:
            unique_tokens.add(token)
    return unique_tokens

d = extract_unique_tokens(vocab)

# %%
sdef encode(mapping, text):
    encoded_text = []
    smap = set(mapping.keys())
    while text:
        i = 0
        for _ in range(1,len(text)+1):
            if text[:i+1] not in smap:
                break
            else:
                i += 1
        encoded_text.append(mapping[text[:i]])
        text = text[i:]
    return encoded_text

def decode(inverted_mapping, encoded_text):
    return [inverted_mapping[c] for c in encoded_text]

# Example usage
#mapping = {token: i for i, token in enumerate(extract_unique_tokens(vocab))}
#inverted_mapping = {v: k for k, v in mapping.items()}
#text = train_text
#encoded_text = encode(mapping, text)
#print(decode(inverted_mapping, encoded_text))

# %%
train_ids = encode(mapping, train_text)
train_ids.tofile('train.bin')
val_ids = encode(mapping, val_text)
val_ids.tofile('val.bin')

# %%
token_map = {'itos':mapping, 'stoi':inverted_mapping, 'vocab_size':len(mapping)}
import pickle
pickle.dump(token_map, open("meta.pkl", "wb"))
